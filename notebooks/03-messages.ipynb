# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

ai_msg = AIMessage(content="Hello! How can I assist you today?")
ai_msg.text
# Out:
# 'Hello! How can I assist you today?'

# %%
human_msg = HumanMessage(content="What's the weather like today?")
human_msg.text
# Out:
# "What's the weather like today?"

# %%
history = [ai_msg, human_msg]
for i in history:
    i.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hello! How can I assist you today?
# ================================ Human Message =================================
#
# What's the weather like today?

# %%
history + [AIMessage(content="Hello! How can I assist you today?")]
# Out:
# [AIMessage(content='Hello! How can I assist you today?', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content="What's the weather like today?", additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Hello! How can I assist you today?', additional_kwargs={}, response_metadata={})]
